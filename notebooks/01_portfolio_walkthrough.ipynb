# %% [markdown]
# # Spotify Hit Prediction - Portfolio Walkthrough
#
# This notebook summarises the main analysis from the Spotify Hit Prediction project. The original work was a longer group coursework notebook. For this GitHub version, the reusable code has been moved into the `src/` folder, and selected visual outputs are saved in `images/key_charts/`.
#
# The raw dataset is not included because it is too large. Download it from Kaggle and place it in `data/raw/universal_top_spotify_songs.csv` before running the project.

# %% [markdown]
# ## 1. Project question
#
# The project asks: **what makes a song popular on Spotify?**
#
# It explores this through four parts: song title analysis, regional and seasonal audio-feature patterns, regression modelling for average popularity, and classification modelling for long-term chart presence.

# %% [markdown]
# ## 2. Example exploratory outputs
#
# The chart below shows the correlation between selected audio features and average popularity in the processed modelling dataset.
#
# ![Correlation between features and popularity](../images/key_charts/correlation_features_popularity.png)

# %% [markdown]
# The boxplot below compares monthly average popularity distributions in the original analysis.
#
# ![Popularity distribution by month](../images/key_charts/popularity_distribution_by_month.png)

# %% [markdown]
# ## 3. Text and sentiment analysis
#
# The original notebook also included word clouds for English-speaking countries. This gave a quick view of repeated terms in song titles.
#
# ![GB word cloud](../images/key_charts/wordcloud_gb.png)
#
# ![US word cloud](../images/key_charts/wordcloud_us.png)

# %% [markdown]
# ## 4. Regional and seasonal patterns
#
# The project compared audio features across countries and months. The map below shows one example: danceability by country.
#
# ![Danceability by country](../images/key_charts/danceability_by_country.png)

# %% [markdown]
# Seasonal trends were also explored by comparing monthly averages of audio features.
#
# ![Monthly audio features](../images/key_charts/monthly_audio_features.png)

# %% [markdown]
# ## 5. Model results
#
# The original project compared several regression models, with Random Forest performing strongest in the initial model comparison.
#
# The classification model was used to predict whether a song would remain in the charts for more than two months. The saved output below includes the confusion matrix, feature importance and prediction confidence distribution.
#
# ![Classification model analysis](../images/key_charts/classification_model_analysis.png)

# %% [markdown]
# ## 6. Reproducible Python workflow
#
# The GitHub version uses Python modules in `src/` to make the project easier to run and maintain. The main command is:

# %%
# Run from the repository root, not from inside this notebook:
# python src/main.py

# %% [markdown]
# The main runner checks whether the raw dataset exists, creates the processed monthly dataset, runs the models, and saves model outputs in the `outputs/` folder.

# %%
from pathlib import Path

raw_path = Path("../data/raw/universal_top_spotify_songs.csv")
processed_path = Path("../data/processed/spotify_monthly_2024.csv")

raw_path, processed_path

# %% [markdown]
# ## 7. Notes
#
# The saved images come from the original notebook outputs. If the Kaggle dataset is downloaded at a later date, some figures and model results may differ because the dataset is updated over time.
